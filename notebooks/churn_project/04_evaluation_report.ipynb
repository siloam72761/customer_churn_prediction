# %%
import joblib
import pandas as pd
from sklearn.model_selection import train_test_split



#저장된 모델, feature 불러오기
lg_loaded = joblib.load("../../results/final_lg_model.pkl")
feature_names = joblib.load("../../results/feature_names.pkl")

#전처리된 데이터 불러오기
customer_churn_reviews = pd.read_csv("../../data/customer_churn_preprocessed.csv", index_col = 0)
X = df.drop('Churn', axis=1)
y = df['Churn']

#feature 순서 맞추기
X = X[feature_names]

X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, random_state=42, stratify=y
)

#예측 확률 불러오기 (ROC Curve 등 시각화에 필요)
y_proba = lg_loaded.predict_proba(X_test)[:,1]
y_pred = (y_proba >= 0.25).astype(int) #threshold 조정 가능
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[13], line 24
#      19 X_train, X_test, y_train, y_test = train_test_split(
#      20     X, y, test_size=0.3, random_state=42, stratify=y
#      21 )
#      23 #예측 확률 불러오기 (ROC Curve 등 시각화에 필요)
# ---> 24 y_proba = lg_loaded.predict_proba(X_test)[:,1]
#      25 y_pred = (y_proba >= 0.25).astype(int) #threshold 조정 가능
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\linear_model\_logistic.py:1428, in LogisticRegression.predict_proba(self, X)
#    1423 ovr = self.multi_class in ["ovr", "warn"] or (
#    1424     self.multi_class in ["auto", "deprecated"]
#    1425     and (self.classes_.size <= 2 or self.solver == "liblinear")
#    1426 )
#    1427 if ovr:
# -> 1428     return super()._predict_proba_lr(X)
#    1429 else:
#    1430     decision = self.decision_function(X)
#
# ...

# %%
df = pd.read_csv("../../data/customer_churn_preprocessed.csv")
print(df.head())
print(df.dtypes)
# Out:
#    gender  SeniorCitizen  Partner  Dependents    tenure  PhoneService  \
# 0       0              0        1           0 -1.277445             0
# 1       1              0        0           0  0.066327             1
# 2       1              0        0           0 -1.236724             1
# 3       1              0        0           0  0.514251             0
# 4       0              0        0           0 -1.236724             1
#
#    PaperlessBilling  MonthlyCharges  TotalCharges  Churn  ...  \
# 0                 1       -1.160323     -0.994242      0  ...
# 1                 0       -0.259629     -0.173244      0  ...
# 2                 1       -0.362660     -0.959674      1  ...
# 3                 0       -0.746535     -0.194766      0  ...
# 4                 1        0.197365     -0.940470      1  ...
#
#    StreamingMovies_No  StreamingMovies_No internet service  \
# 0                True                                False
# ...
